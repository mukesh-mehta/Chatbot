# %%
import goibibo

# %%
goibibo.getHotelResp("roorkee")
# Out:
# 1268976774218365852
# [{'category': ['Business', 'Luxury'],
#   'facilities': {'cmapped': {'BUSNS': {'dn': 'Business Services'},
#     'FRINTRNT': {'dn': 'Free Internet'},
#     'INTRNT': {'dn': 'Internet'},
#     'LNDRY': {'dn': 'Laundry Service'},
#     'PRKG': {'dn': 'Parking Facility'},
#     'RMSVC': {'dn': 'Room Service'},
#     'RSTRNT': {'dn': 'Restaurant/Coffee Shop'}},
#    'mapped': ['Free Internet',
#     'Laundry Service',
#     'Restaurant/Coffee Shop',
#     'Business Services',
#     'Parking Facility',
#     'Internet',
#     'Room Service']},
#   'id': '3453296553713945792',
#   'location': {'lat': 29.921053, 'long': 77.82994},
#   'name': 'Hometel Roorkee',
#   'pincode': '247667',
#   'rating': '4.3'},
#  {'category': ['Budget', 'Business'],
#   'facilities': {'cmapped': {'BUSNS': {'dn': 'Business Services'},
#     'LNDRY': {'dn': 'Laundry Service'},
#     'PRKG': {'dn': 'Parking Facility'},
#     'RMSVC': {'dn': 'Room Service'}},
# ...

# %%
goibibo.getFlightsResp("bangalore","mumbai","20170819")
# Out:
# http://developer.goibibo.com/api/search/
# BLR
# BOM
# 20170819
# ...

# %%
goibibo.getBusesResp("bangalore","hyderabad","20170819","20170825")
# Out:
# {'onward': [{'arrival_time': '06:30',
#    'boarding_points': {'list': [{'BPId': '1671808',
#       'BPLocation': 'Jayanagar 4th block - cool joint signal',
#       'BPTime': '2017-08-19T20:30:00Z'},
#      {'BPId': '1671858',
#       'BPLocation': 'Eastend circle - royal enfield',
#       'BPTime': '2017-08-19T20:40:00Z'},
#      {'BPId': '1672563',
#       'BPLocation': 'Silkboard - krishna bhavan',
#       'BPTime': '2017-08-19T21:00:00Z'},
#      {'BPId': '1671915',
#       'BPLocation': 'Hsr layout - nandas',
#       'BPTime': '2017-08-19T21:10:00Z'},
#      {'BPId': '1671972',
#       'BPLocation': 'Bellandur - maruthi showroom',
#       'BPTime': '2017-08-19T21:15:00Z'},
#      {'BPId': '1672034',
#       'BPLocation': 'Marathahalli - airtel 4g',
#       'BPTime': '2017-08-19T21:30:00Z'},
#      {'BPId': '1672099',
#       'BPLocation': 'Mahadevpura - more',
#       'BPTime': '2017-08-19T21:40:00Z'},
#      {'BPId': '1672171',
# ...
